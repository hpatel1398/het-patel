# %% [markdown]
# <a href="https://colab.research.google.com/github/hpatel1398/het-patel/blob/master/EDA_OurScrapedData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
overall=pd.read_csv("/content/Data/AllContentData.csv")
overall#.head()
# Out:
#         jw_entity_id  ...                                     original_title
# 0            tm10000  ...                                          Jury Duty
# 1           tm100004  ...                                 Alors... Heureux ?
# 2           tm100000  ...                              El difunto es un vivo
# 3             tm1000  ...  1983 FIA Formula One World Championship Season...
# 4           tm100001  ...                                    The Lucky Texan
# ...              ...  ...                                                ...
# 4937832     tss99974  ...                                        Temporada 2
# 4937833     tss99985  ...                                           Season 7
# 4937834     tss99987  ...                                           Season 5
# 4937835      tss9999  ...                                           Season 4
# 4937836     tss99999  ...                                          Staffel 1
#
# [4937837 rows x 7 columns]

# %%
shows=overall[overall['object_type']=='show']
show_season=overall[overall['object_type']=='show_season']
movies=overall[overall['object_type']=='movie']

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="object_type", data=overall, palette="Set2")

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(x="tmdb_popularity", data=movies, palette="Set2", order=movies['tmdb_popularity'].value_counts().index[0:15])

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y="original_release_year", data=movies, palette="Set2", order=movies['original_release_year'].value_counts().index[0:15])

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y="original_release_year", data=shows, palette="Set2", order=shows['original_release_year'].value_counts().index[0:15])

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y="original_release_year", data=show_season, palette="Set2", order=show_season['original_release_year'].value_counts().index[0:15])

# %%
#show_episode=overall[overall['object_type']=='show_episode']
top=movies.sort_values(by='tmdb_popularity', ascending=False)
top20=top[0:20]
top20.plot(kind='bar',x='title',y='tmdb_popularity', color='red')
